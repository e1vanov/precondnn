# %% [markdown]
# # Imports

# %%
import sys
sys.path.append('../../../src/utils')

# %%
from my_loss import SpecRadLoss, MatrixNormLoss, KCondNumberLoss

# %%
import numpy as np
import matplotlib.pyplot as plt

# Torch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# Logging
import wandb
from tqdm import tqdm

# %%
if torch.cuda.is_available():
    device = 'cuda:0'
else:
    device = 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# # Data

# %%
ds_path = '../../../datasets/ds03'

# %%
X_train = torch.utils.data.TensorDataset(torch.load(ds_path + '/train.pt').type(torch.float).to(device))
X_valid = torch.utils.data.TensorDataset(torch.load(ds_path + '/test.pt').type(torch.float).to(device))

# %%
train_dataloader = DataLoader(X_train, batch_size=32, shuffle=True, drop_last=True)
valid_dataloader = DataLoader(X_valid, batch_size=32, shuffle=False)

# %% [markdown]
# # Spectrum drawer

# %%
from spectrum_drawers import draw_spectrum

# %%
@torch.no_grad()
def draw_random_spectrums(net, val_ds, h=3, w=3, path='./spectrum.svg', indices=None):
    
    if indices is None:
        indices = np.random.choice(len(val_ds), h * w, replace=False)
    
    assert len(indices) == h * w
        
    input_data = val_ds[indices][0]

    net.eval()
    output_data = net(input_data)
    
    input_data = input_data.cpu().detach().numpy()
    output_data = output_data.cpu().detach().numpy()
    
    draw_spectrum(input_data, output_data, h, w, path)

# %% [markdown]
# # Model

# %%
class MyPerceptronFD(nn.Module):
    
    def __init__(self, dim=64):
        
        super().__init__()
        self.dim = dim
        
        self.fc1 = nn.Linear(dim, 2 * dim)
        self.ac1 = nn.ReLU()
        
        self.fc2 = nn.Linear(2 * dim, 2 * dim)
        self.ac2 = nn.ReLU()
        
        self.fc3 = nn.Linear(2 * dim, dim)
        
    def forward(self, x):
        
        x = self.ac1(self.fc1(x))
        x = self.ac2(self.fc2(x))
        
        return self.fc3(x)

# %% [markdown]
# # Train loop

# %%
val_indices = np.random.choice(len(X_valid), 4 * 4, replace=False)

# %%
@torch.no_grad()
def evaluate(net, 
             model_name,
             epoch_num, 
             device):
    
    net.eval()
    draw_random_spectrums(net, X_valid, 4, 4, path=f'./{model_name}/spectrum_epoch{epoch_num}.svg', 
                          indices=val_indices)

def train(epoch_num, 
          net, 
          optimizer, 
          criterion,
          scheduler,
          train_dataloader, 
          valid_dataloader, 
          device, 
          name,
          model_name):

    wandb.init(project="loss_choice_01", name=name)
    global_step = 0
    net = net.to(device)

    iters_per_epoch = len(train_dataloader)

    for epoch in tqdm(range(epoch_num)):
        
        avg_valid_eig_module_pred  = evaluate(net, model_name, epoch, device)
                
        net.train()
        
        for inputs in train_dataloader:
            
            inputs = inputs[0].to(device)
            
            outputs = net(inputs)
            
            loss = criterion(inputs, outputs)
            loss.backward()
            
            optimizer.step()
            
            wandb.log({"train/loss": loss.item()}, step=global_step)

            global_step += 1
            
        scheduler.step()

    wandb.finish()

# %% [markdown]
# # SpecRadLoss

# %%
net = MyPerceptronFD(128)
criterion = SpecRadLoss(n=5,n_samples=100, alpha_reg=0.)
optimizer = optim.Adam(net.parameters(), lr=5e-5)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.99)

# %%
train(
    epoch_num=20,
    net=net,
    optimizer=optimizer,
    criterion=criterion,
    scheduler=scheduler,
    train_dataloader=train_dataloader,
    valid_dataloader=valid_dataloader,
    device=device,
    name="SpecRadLoss",
    model_name="specradloss_model")
# Out:
# wandb: Currently logged in as: s02210401 (cmcmsu). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.8
# Run data is saved locally in <code>/home/egor/desktop/tmp/precondnn/exps/loss_choice_exps/exp01/wandb/run-20240926_005104-hhtb10zo</code>
# Syncing run <strong><a href='https://wandb.ai/cmcmsu/loss_choice_01/runs/hhtb10zo' target="_blank">SpecRadLoss</a></strong> to <a href='https://wandb.ai/cmcmsu/loss_choice_01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cmcmsu/loss_choice_01' target="_blank">https://wandb.ai/cmcmsu/loss_choice_01</a>
#  View run at <a href='https://wandb.ai/cmcmsu/loss_choice_01/runs/hhtb10zo' target="_blank">https://wandb.ai/cmcmsu/loss_choice_01/runs/hhtb10zo</a>
#   0%|                                        | 0/20 [00:00<?, ?it/s]
#   0%|                                        | 0/20 [03:08<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train(
#       2     epoch_num=20,
#       3     net=net,
#       4     optimizer=optimizer,
#       5     criterion=criterion,
#       6     scheduler=scheduler,
#       7     train_dataloader=train_dataloader,
#       8     valid_dataloader=valid_dataloader,
#       9     device=device,
#      10     name="SpecRadLoss",
#      11     model_name="specradloss_model")
#
# Cell In[12], line 41, in train(epoch_num, net, optimizer, criterion, scheduler, train_dataloader, valid_dataloader, device, name, model_name)
#      38 outputs = net(inputs)
#      40 loss = criterion(inputs, outputs)
# ---> 41 loss.backward()
#      43 optimizer.step()
#      45 wandb.log({"train/loss": loss.item()}, step=global_step)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
torch.save(net.state_dict(), './specradloss_model/model.pt')

# %%
draw_random_spectrums(net, X_valid, 4, 4, path='./specradloss_model/spectrum.svg')

# %% [markdown]
# # Frobenius norm

# %%
net = MyPerceptronFD()
criterion = MatrixNormLoss('fro')
optimizer = optim.Adam(net.parameters(), lr=5e-5)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.99)

# %%
train(
    epoch_num=20,
    net=net,
    optimizer=optimizer,
    criterion=criterion,
    scheduler=scheduler,
    train_dataloader=train_dataloader,
    valid_dataloader=valid_dataloader,
    device=device,
    name="FrobeniusNormLoss")
# Out:
# Tracking run with wandb version 0.17.8
# Run data is saved locally in <code>/home/egor/desktop/tmp/precondnn/loss_choice_exp/wandb/run-20240922_223651-m2ttiej1</code>
# Syncing run <strong><a href='https://wandb.ai/cmcmsu/loss_choice/runs/m2ttiej1' target="_blank">FrobeniusNormLoss</a></strong> to <a href='https://wandb.ai/cmcmsu/loss_choice' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cmcmsu/loss_choice' target="_blank">https://wandb.ai/cmcmsu/loss_choice</a>
#  View run at <a href='https://wandb.ai/cmcmsu/loss_choice/runs/m2ttiej1' target="_blank">https://wandb.ai/cmcmsu/loss_choice/runs/m2ttiej1</a>
# 100%|███████████████████████████████| 20/20 [03:50<00:00, 11.53s/it]
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/loss</td><td>█▅▅▄▄▃▂▂▃▂▂▂▃▂▂▂▁▃▂▂▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/loss</td><td>3.2193</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">FrobeniusNormLoss</strong> at: <a href='https://wandb.ai/cmcmsu/loss_choice/runs/m2ttiej1' target="_blank">https://wandb.ai/cmcmsu/loss_choice/runs/m2ttiej1</a><br/> View project at: <a href='https://wandb.ai/cmcmsu/loss_choice' target="_blank">https://wandb.ai/cmcmsu/loss_choice</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240922_223651-m2ttiej1/logs</code>
# wandb version 0.18.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
torch.save(net.state_dict(), './frobeniusnormloss_model/model.pt')

# %%
draw_random_spectrums(net, X_valid, 4, 4, path='./frobeniusnormloss_model/spectrum.svg')

# %% [markdown]
# # Spectral norm

# %%
net = MyPerceptronFD()
criterion = MatrixNormLoss(2)
optimizer = optim.Adam(net.parameters(), lr=5e-5)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.99)

# %%
train(
    epoch_num=20,
    net=net,
    optimizer=optimizer,
    criterion=criterion,
    scheduler=scheduler,
    train_dataloader=train_dataloader,
    valid_dataloader=valid_dataloader,
    device=device,
    name="SpectralNormLoss")
# Out:
# Tracking run with wandb version 0.17.8
# Run data is saved locally in <code>/home/egor/desktop/tmp/precondnn/loss_choice_exp/wandb/run-20240922_222951-hyb4u4z3</code>
# Syncing run <strong><a href='https://wandb.ai/cmcmsu/loss_choice/runs/hyb4u4z3' target="_blank">SpectralNormLoss</a></strong> to <a href='https://wandb.ai/cmcmsu/loss_choice' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cmcmsu/loss_choice' target="_blank">https://wandb.ai/cmcmsu/loss_choice</a>
#  View run at <a href='https://wandb.ai/cmcmsu/loss_choice/runs/hyb4u4z3' target="_blank">https://wandb.ai/cmcmsu/loss_choice/runs/hyb4u4z3</a>
# 100%|███████████████████████████████| 20/20 [05:55<00:00, 17.79s/it]
# VBox(children=(Label(value='0.001 MB of 0.002 MB uploaded\r'), FloatProgress(value=0.6720075400565504, max=1.0…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/loss</td><td>█▅▄▃▃▃▂▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/loss</td><td>0.72933</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SpectralNormLoss</strong> at: <a href='https://wandb.ai/cmcmsu/loss_choice/runs/hyb4u4z3' target="_blank">https://wandb.ai/cmcmsu/loss_choice/runs/hyb4u4z3</a><br/> View project at: <a href='https://wandb.ai/cmcmsu/loss_choice' target="_blank">https://wandb.ai/cmcmsu/loss_choice</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240922_222951-hyb4u4z3/logs</code>
# wandb version 0.18.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
torch.save(net.state_dict(), './spectralnormloss_model/model.pt')

# %%
draw_random_spectrums(net, X_valid, 4, 4, path='./spectralnormloss_model/spectrum.svg')

# %% [markdown]
# # Nuclear norm

# %%
net = MyPerceptronFD(128)
criterion = MatrixNormLoss('nuc')
optimizer = optim.Adam(net.parameters(), lr=5e-5)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.99)

# %%
train(
    epoch_num=20,
    net=net,
    optimizer=optimizer,
    criterion=criterion,
    scheduler=scheduler,
    train_dataloader=train_dataloader,
    valid_dataloader=valid_dataloader,
    device=device,
    name="NuclearNormLoss",
    model_name="nuclearnormloss_model")
# Out:
# wandb: Currently logged in as: s02210401 (cmcmsu). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.8
# Run data is saved locally in <code>/home/egor/desktop/tmp/precondnn/exps/loss_choice_exps/exp01/wandb/run-20240926_010032-8fsc9pt6</code>
# Syncing run <strong><a href='https://wandb.ai/cmcmsu/loss_choice_01/runs/8fsc9pt6' target="_blank">NuclearNormLoss</a></strong> to <a href='https://wandb.ai/cmcmsu/loss_choice_01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cmcmsu/loss_choice_01' target="_blank">https://wandb.ai/cmcmsu/loss_choice_01</a>
#  View run at <a href='https://wandb.ai/cmcmsu/loss_choice_01/runs/8fsc9pt6' target="_blank">https://wandb.ai/cmcmsu/loss_choice_01/runs/8fsc9pt6</a>
#  30%|█████████▌                      | 6/20 [09:53<23:04, 98.89s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train(
#       2     epoch_num=20,
#       3     net=net,
#       4     optimizer=optimizer,
#       5     criterion=criterion,
#       6     scheduler=scheduler,
#       7     train_dataloader=train_dataloader,
#       8     valid_dataloader=valid_dataloader,
#       9     device=device,
#      10     name="NuclearNormLoss",
#      11     model_name="nuclearnormloss_model")
#
# Cell In[12], line 43, in train(epoch_num, net, optimizer, criterion, scheduler, train_dataloader, valid_dataloader, device, name, model_name)
#      40 loss = criterion(inputs, outputs)
#      41 loss.backward()
# ---> 43 optimizer.step()
#      45 wandb.log({"train/loss": loss.item()}, step=global_step)
#      47 global_step += 1
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:75, in LRScheduler.__init__.<locals>.with_counter.<locals>.wrapper(*args, **kwargs)
#      73 instance._step_count += 1
#      74 wrapped = func.__get__(instance, cls)
# ---> 75 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/optim/optimizer.py:391, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     386         else:
#     387             raise RuntimeError(
#     388                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     389             )
# --> 391 out = func(*args, **kwargs)
#     392 self._optimizer_step_code()
#     394 # call optimizer step post hooks
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/optim/adam.py:168, in Adam.step(self, closure)
#     157     beta1, beta2 = group['betas']
#     159     has_complex = self._init_group(
#     160         group,
#     161         params_with_grad,
#    (...)
#     165         max_exp_avg_sqs,
#     166         state_steps)
# --> 168     adam(
#     169         params_with_grad,
#     170         grads,
#     171         exp_avgs,
#     172         exp_avg_sqs,
#     173         max_exp_avg_sqs,
#     174         state_steps,
#     175         amsgrad=group['amsgrad'],
#     176         has_complex=has_complex,
#     177         beta1=beta1,
#     178         beta2=beta2,
#     179         lr=group['lr'],
#     180         weight_decay=group['weight_decay'],
#     181         eps=group['eps'],
#     182         maximize=group['maximize'],
#     183         foreach=group['foreach'],
#     184         capturable=group['capturable'],
#     185         differentiable=group['differentiable'],
#     186         fused=group['fused'],
#     187         grad_scale=getattr(self, "grad_scale", None),
#     188         found_inf=getattr(self, "found_inf", None),
#     189     )
#     191 return loss
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/optim/adam.py:318, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     315 else:
#     316     func = _single_tensor_adam
# --> 318 func(params,
#     319      grads,
#     320      exp_avgs,
#     321      exp_avg_sqs,
#     322      max_exp_avg_sqs,
#     323      state_steps,
#     324      amsgrad=amsgrad,
#     325      has_complex=has_complex,
#     326      beta1=beta1,
#     327      beta2=beta2,
#     328      lr=lr,
#     329      weight_decay=weight_decay,
#     330      eps=eps,
#     331      maximize=maximize,
#     332      capturable=capturable,
#     333      differentiable=differentiable,
#     334      grad_scale=grad_scale,
#     335      found_inf=found_inf)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/optim/adam.py:441, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     439         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     440     else:
# --> 441         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     443     param.addcdiv_(exp_avg, denom, value=-step_size)
#     445 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
torch.save(net.state_dict(), './nuclearnormloss_model/model.pt')

# %% [markdown]
# # KCondNumberLoss

# %%
net = MyPerceptronFD(128)
criterion = KCondNumberLoss()
optimizer = optim.Adam(net.parameters(), lr=5e-5)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.99)

# %%
train(
    epoch_num=20,
    net=net,
    optimizer=optimizer,
    criterion=criterion,
    scheduler=scheduler,
    train_dataloader=train_dataloader,
    valid_dataloader=valid_dataloader,
    device=device,
    name="KCondNumberLoss",
    model_name="kcondnumberloss_model")
# Out:
# wandb: Currently logged in as: s02210401 (cmcmsu). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.8
# Run data is saved locally in <code>/home/egor/desktop/tmp/precondnn/exps/loss_choice_exps/exp01/wandb/run-20240926_011223-co43j1i0</code>
# Syncing run <strong><a href='https://wandb.ai/cmcmsu/loss_choice_01/runs/co43j1i0' target="_blank">KCondNumberLoss</a></strong> to <a href='https://wandb.ai/cmcmsu/loss_choice_01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cmcmsu/loss_choice_01' target="_blank">https://wandb.ai/cmcmsu/loss_choice_01</a>
#  View run at <a href='https://wandb.ai/cmcmsu/loss_choice_01/runs/co43j1i0' target="_blank">https://wandb.ai/cmcmsu/loss_choice_01/runs/co43j1i0</a>
#   5%|█▌                              | 1/20 [01:00<19:01, 60.10s/it]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train(
#       2     epoch_num=20,
#       3     net=net,
#       4     optimizer=optimizer,
#       5     criterion=criterion,
#       6     scheduler=scheduler,
#       7     train_dataloader=train_dataloader,
#       8     valid_dataloader=valid_dataloader,
#       9     device=device,
#      10     name="KCondNumberLoss",
#      11     model_name="kcondnumberloss_model")
#
# Cell In[12], line 30, in train(epoch_num, net, optimizer, criterion, scheduler, train_dataloader, valid_dataloader, device, name, model_name)
#      26 iters_per_epoch = len(train_dataloader)
#      28 for epoch in tqdm(range(epoch_num)):
# ---> 30     avg_valid_eig_module_pred  = evaluate(net, model_name, epoch, device)
#      32     net.train()
#      34     for inputs in train_dataloader:
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[12], line 8, in evaluate(net, model_name, epoch_num, device)
#       1 @torch.no_grad()
#       2 def evaluate(net,
#       3              model_name,
#       4              epoch_num,
#       5              device):
#       7     net.eval()
# ----> 8     draw_random_spectrums(net, X_valid, 4, 4, path=f'./{model_name}/spectrum_epoch{epoch_num}.svg',
#       9                           indices=val_indices)
#
# File ~/miniconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[9], line 17, in draw_random_spectrums(net, val_ds, h, w, path, indices)
#      14 input_data = input_data.cpu().detach().numpy()
#      15 output_data = output_data.cpu().detach().numpy()
# ---> 17 draw_spectrum(input_data, output_data, h, w, path)
#
# File ~/desktop/tmp/precondnn/exps/loss_choice_exps/exp01/../../../src/utils/spectrum_drawers.py:26, in draw_spectrum(t, c_inv, h, w, path)
#      22 C_inv = sp.linalg.circulant(c_inv[ind])
#      24 A = np.eye(t.shape[1]) - T @ C_inv
# ---> 26 lambdas = np.linalg.eigvals(A)
#      28 ax[i][j].set_xlim([-2., 2.])
#      29 ax[i][j].set_ylim([-2., 2.])
#
# File ~/miniconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:1068, in eigvals(a)
#    1066 _assert_stacked_2d(a)
#    1067 _assert_stacked_square(a)
# -> 1068 _assert_finite(a)
#    1069 t, result_t = _commonType(a)
#    1071 extobj = get_linalg_error_extobj(
#    1072     _raise_linalgerror_eigenvalues_nonconvergence)
#
# File ~/miniconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:218, in _assert_finite(*arrays)
#     216 for a in arrays:
#     217     if not isfinite(a).all():
# --> 218         raise LinAlgError("Array must not contain infs or NaNs")
#
# LinAlgError: Array must not contain infs or NaNs
